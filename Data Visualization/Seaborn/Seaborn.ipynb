# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(df['total_bill'],bins=30)

# %%
sns.jointplot(x='total_bill' , y= 'tip', data=df)

# %%
sns.jointplot(x='total_bill' , y= 'tip', data=df, kind='reg')

# %%
sns.jointplot(x='total_bill' , y= 'tip', data=df, kind='hex')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='sex')

# %%
sns.barplot(x='sex', y= 'total_bill', data= df)

# %%
sns.barplot(x='sex', y = 'tip', data=df)

# %%
df['tip_normal'] = (df['tip']/df['total_bill'])*100

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_normal
# 0       16.99  1.01  Female     No  Sun  Dinner     2    5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3   16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3   16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2   13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4   14.680765

# %%
sns.barplot(x='sex', y = 'tip_normal', data=df)

# %%
sns.barplot(x='smoker', y = 'tip_normal', data=df)

# %%
sns.barplot(x='day', y = 'tip_normal', data=df)
