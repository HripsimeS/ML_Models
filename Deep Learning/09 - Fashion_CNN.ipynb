# %%
import numpy as np

# %%
X_train = np.load('Datasets/Fashion_MNIST/X_train.npy')
X_test = np.load('Datasets/Fashion_MNIST/X_test.npy')
y_train = np.load('Datasets/Fashion_MNIST/y_train.npy')
y_test = np.load('Datasets/Fashion_MNIST/y_test.npy')

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
y_test.shape
# Out:
# (10000,)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(sparse=False)

# %%
encoder.fit(y_train.reshape(-1, 1))
# Out:
# OneHotEncoder(categorical_features='all', dtype=<class 'numpy.float64'>,
#        handle_unknown='error', n_values='auto', sparse=False)

# %%
y_train = encoder.transform(y_train.reshape(-1, 1))
y_test = encoder.transform(y_test.reshape(-1, 1))

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
def get_next_batch(X, y, size):
    m = X.shape[0]
    index = np.random.permutation(np.arange(m))
    for i in range(m//size):
        batch_i = index[i*size: i*size+size]
        yield X[batch_i], y[batch_i]

# %% [markdown]
# ### Training

# %%
import tensorflow as tf

# %%
def conv_layer(X, channels, kernel_size, strides=[1, 1, 1, 1], kernel_initializer=None, reuse=False, name="conv"):
    with tf.variable_scope("Var_"+name, reuse=reuse):
        
        if kernel_initializer:
            initializer = kernel_initializer()
        else:
            initializer = tf.random_normal_initializer(stddev=0.01)
        
        shape = [kernel_size[0], kernel_size[1], X.shape[3].value, channels]
        
        if reuse:
            W = tf.get_variable('W')
            b = tf.get_variable('B')
        else:
            W = tf.get_variable(shape=shape, initializer=initializer, name='W')
            b = tf.get_variable(initializer=tf.constant(0.1, shape=[channels]), name='B')

        conv = tf.nn.conv2d(X, W, strides=strides, padding="SAME")
        act = tf.nn.relu(conv + b)
        
        tf.summary.histogram("weights", W)
        tf.summary.histogram("biases", b)
        tf.summary.histogram("activations", act)
        
        return act

# %%
def fc_layer(X, units, activation=None, kernel_initializer=None, regularizer=None, reuse=False, name='FC'):
    
    with tf.variable_scope("Var_"+name, reuse=reuse):

        if kernel_initializer:
            initializer = kernel_initializer()
        else:
            initializer = tf.random_normal_initializer(stddev=0.01)

        if reuse:
            W = tf.get_variable('W')
            b = tf.get_variable('B')
        else:
            W = tf.get_variable(shape=[X.shape[1].value, units], initializer=initializer, regularizer=regularizer, name='W')
            b = tf.get_variable(initializer=tf.constant(0.1, shape=[units]), name='B')

        Z = tf.add(tf.matmul(X, W), b)

        if activation:
            A = activation(Z)
        else:
            A = Z

        tf.summary.histogram("weights", W)
        tf.summary.histogram("biases", b)
        tf.summary.histogram("activations", A)

    return A

# %%
def conv_model(X, y, conv_channels, conv_kernels, fc_layers, regularization_rate=0.0, drop_rate=0.0, reuse=False, is_training=True, name="Conv_model"):
    with tf.name_scope(name):
        regularizer = tf.contrib.layers.l2_regularizer(scale=regularization_rate)
        kernel_initializer = tf.contrib.layers.xavier_initializer
        activation = tf.nn.relu
        
        for i, channels in enumerate(conv_channels):
            X = conv_layer(X, channels=channels, kernel_size=conv_kernels[i], kernel_initializer=kernel_initializer, reuse=reuse, name=f"conv_{i}")
            X = tf.nn.max_pool(X, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="SAME")            
        
        dims = np.prod(X.shape.as_list()[1:])
        X = tf.reshape(X, [-1, dims])
        
        for i, layer in enumerate(fc_layers):
            X = fc_layer(X, layer, activation, kernel_initializer, regularizer, reuse=reuse, name=f"fc{i+1}")
            X = tf.layers.dropout(X, rate=drop_rate, training=is_training)

        output = fc_layer(X, y.shape[1].value, kernel_initializer=kernel_initializer, regularizer=regularizer, reuse=reuse, name=f"last_fc" )
        tf.summary.histogram('logits', output)
    return output

# %%
def mnist_model(X_train, y_train, conv_channels, conv_kernels, layers, learning_rate, epochs, batch_size,
                l2_rate, drop_rate, logdir, X_test, y_test, print_acc=False):
    tf.reset_default_graph()
    with tf.Session() as sess:
        
        n_features = X_train.shape[1]
        n_labels = y_train.shape[1]
        
        X = tf.placeholder(tf.float32, shape=[None, n_features], name="x")
        x_image = tf.reshape(X, [-1, 28, 28, 1]) #MNIST SHAPE
        paddings = tf.constant([[0, 0], [2, 2], [2, 2], [0, 0]])
        x_image = tf.pad(x_image, paddings)
        y = tf.placeholder(tf.float32, shape=[None, n_labels], name="labels")


        train_logits = conv_model(x_image, y, conv_channels, conv_kernels, fc_layers=layers, regularization_rate=l2_rate, drop_rate=drop_rate, reuse=False, is_training=True, name="Conv_Model")
        test_logits = conv_model(x_image, y, conv_channels, conv_kernels, fc_layers=layers, reuse=True, is_training=False, name="Conv_Eval_Model")

        with tf.name_scope("loss"):
            loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(
                                  logits=train_logits, labels=y), name="loss")
            tf.summary.scalar("loss", loss)

        with tf.name_scope("train"):
            train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)

        with tf.name_scope("test_accuracy"):
            correct_prediction = tf.equal(tf.argmax(test_logits, 1), tf.argmax(y, 1))
            test_accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
            tf.summary.scalar("test_accuracy", test_accuracy)
        
        with tf.name_scope("train_accuracy"):
            correct_prediction = tf.equal(tf.argmax(train_logits, 1), tf.argmax(y, 1))
            train_accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
            tf.summary.scalar("train_accuracy", train_accuracy)

        summ = tf.summary.merge_all()

        saver = tf.train.Saver()

        sess.run(tf.global_variables_initializer())
        writer = tf.summary.FileWriter(f"./summary/{logdir}")
        writer.add_graph(sess.graph)

        for epoch in range(1, epochs+1):
            for X_batch, y_batch in get_next_batch(X_train, y_train, batch_size):
                sess.run(train_step, {X: X_batch, y: y_batch})
                
            if print_acc and epoch%10 == 0:
                train_sample = get_next_batch(X_train, y_train, 1000).__next__()
                test_sample = get_next_batch(X_test, y_test, 1000).__next__()
                
                test_acc, s = sess.run([test_accuracy, summ],  {X: test_sample[0], y: test_sample[1]})
                train_l, train_acc = sess.run([loss, train_accuracy], {X: train_sample[0], y: train_sample[1]})
                print("Epoch:", np.round(epoch, 4),
                      "Train Loss:", np.round(train_l, 4),
                      "Train accuracy:", np.round(train_acc, 4),
                      "Test accuracy:", np.round(test_acc,4))
                writer.add_summary(s, epoch)
                saver.save(sess, f"./model/{logdir}")

# %%
from sklearn.model_selection import ParameterGrid

# %%
param_grid = [{'conv_channels':[[32, 64], [64, 128], [128, 256]],
               'conv_kernels':[[[5, 5], [3, 3]], [[3, 3] , [3, 3]]]},
              {'conv_channels':[[32, 64, 128], [64, 128, 256], [128, 256, 512]],
               'conv_kernels':[[[5, 5], [3, 3], [3, 3]], [[3, 3], [3, 3], [3, 3]]]}]

# %%
for params in ParameterGrid(param_grid):
    name = ",".join([f"{k}={v}" for k, v in params.items()])
    
    print("\n\n", name)
    mnist_model(X_train=X_train, y_train=y_train, 
                layers=[256, 128], learning_rate=1e-5, epochs=300, batch_size=32, 
                l2_rate=0.0, drop_rate=0.5, logdir=name, X_test=X_test, y_test=y_test, print_acc=True, **params)
# Out:
#  conv_channels=[32, 64],conv_kernels=[[5, 5], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.672 Train accuracy: 0.784 Test accuracy: 0.852
# Epoch: 20 Train Loss: 0.4053 Train accuracy: 0.868 Test accuracy: 0.871
# Epoch: 30 Train Loss: 0.3574 Train accuracy: 0.873 Test accuracy: 0.889
# Epoch: 40 Train Loss: 0.3482 Train accuracy: 0.887 Test accuracy: 0.882
# Epoch: 50 Train Loss: 0.2746 Train accuracy: 0.901 Test accuracy: 0.91
# Epoch: 60 Train Loss: 0.1932 Train accuracy: 0.926 Test accuracy: 0.908
# Epoch: 70 Train Loss: 0.212 Train accuracy: 0.921 Test accuracy: 0.912
# Epoch: 80 Train Loss: 0.2137 Train accuracy: 0.931 Test accuracy: 0.915
# Epoch: 90 Train Loss: 0.1827 Train accuracy: 0.942 Test accuracy: 0.9
# Epoch: 100 Train Loss: 0.1667 Train accuracy: 0.931 Test accuracy: 0.902
# Epoch: 110 Train Loss: 0.1363 Train accuracy: 0.952 Test accuracy: 0.924
# Epoch: 120 Train Loss: 0.1464 Train accuracy: 0.952 Test accuracy: 0.92
# Epoch: 130 Train Loss: 0.1414 Train accuracy: 0.951 Test accuracy: 0.908
# Epoch: 140 Train Loss: 0.0968 Train accuracy: 0.969 Test accuracy: 0.913
# Epoch: 150 Train Loss: 0.0851 Train accuracy: 0.97 Test accuracy: 0.918
# Epoch: 160 Train Loss: 0.0906 Train accuracy: 0.961 Test accuracy: 0.919
# Epoch: 170 Train Loss: 0.0886 Train accuracy: 0.964 Test accuracy: 0.913
# Epoch: 180 Train Loss: 0.097 Train accuracy: 0.966 Test accuracy: 0.93
# Epoch: 190 Train Loss: 0.0652 Train accuracy: 0.973 Test accuracy: 0.91
# Epoch: 200 Train Loss: 0.0859 Train accuracy: 0.97 Test accuracy: 0.927
# Epoch: 210 Train Loss: 0.0855 Train accuracy: 0.967 Test accuracy: 0.906
# Epoch: 220 Train Loss: 0.0828 Train accuracy: 0.966 Test accuracy: 0.912
# Epoch: 230 Train Loss: 0.0599 Train accuracy: 0.972 Test accuracy: 0.917
# Epoch: 240 Train Loss: 0.0605 Train accuracy: 0.978 Test accuracy: 0.915
# Epoch: 250 Train Loss: 0.0586 Train accuracy: 0.983 Test accuracy: 0.909
# Epoch: 260 Train Loss: 0.0751 Train accuracy: 0.974 Test accuracy: 0.918
# Epoch: 270 Train Loss: 0.0428 Train accuracy: 0.983 Test accuracy: 0.902
# Epoch: 280 Train Loss: 0.0482 Train accuracy: 0.982 Test accuracy: 0.929
# Epoch: 290 Train Loss: 0.0498 Train accuracy: 0.982 Test accuracy: 0.925
# Epoch: 300 Train Loss: 0.0506 Train accuracy: 0.981 Test accuracy: 0.909
#
#
#  conv_channels=[32, 64],conv_kernels=[[3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.5748 Train accuracy: 0.807 Test accuracy: 0.839
# Epoch: 20 Train Loss: 0.4529 Train accuracy: 0.833 Test accuracy: 0.875
# Epoch: 30 Train Loss: 0.3693 Train accuracy: 0.88 Test accuracy: 0.897
# Epoch: 40 Train Loss: 0.2703 Train accuracy: 0.907 Test accuracy: 0.899
# Epoch: 50 Train Loss: 0.2774 Train accuracy: 0.906 Test accuracy: 0.891
# Epoch: 60 Train Loss: 0.2581 Train accuracy: 0.906 Test accuracy: 0.894
# Epoch: 70 Train Loss: 0.209 Train accuracy: 0.927 Test accuracy: 0.917
# Epoch: 80 Train Loss: 0.1987 Train accuracy: 0.929 Test accuracy: 0.918
# Epoch: 90 Train Loss: 0.1576 Train accuracy: 0.946 Test accuracy: 0.902
# Epoch: 100 Train Loss: 0.1553 Train accuracy: 0.945 Test accuracy: 0.901
# Epoch: 110 Train Loss: 0.1268 Train accuracy: 0.952 Test accuracy: 0.927
# Epoch: 120 Train Loss: 0.1502 Train accuracy: 0.951 Test accuracy: 0.909
# Epoch: 130 Train Loss: 0.1312 Train accuracy: 0.956 Test accuracy: 0.902
# Epoch: 140 Train Loss: 0.1287 Train accuracy: 0.953 Test accuracy: 0.917
# Epoch: 150 Train Loss: 0.1283 Train accuracy: 0.95 Test accuracy: 0.92
# Epoch: 160 Train Loss: 0.0812 Train accuracy: 0.97 Test accuracy: 0.905
# Epoch: 170 Train Loss: 0.0862 Train accuracy: 0.968 Test accuracy: 0.935
# Epoch: 180 Train Loss: 0.0822 Train accuracy: 0.967 Test accuracy: 0.912
# Epoch: 190 Train Loss: 0.0798 Train accuracy: 0.968 Test accuracy: 0.932
# Epoch: 200 Train Loss: 0.0573 Train accuracy: 0.978 Test accuracy: 0.924
# Epoch: 210 Train Loss: 0.0711 Train accuracy: 0.975 Test accuracy: 0.923
# Epoch: 220 Train Loss: 0.0754 Train accuracy: 0.97 Test accuracy: 0.915
# Epoch: 230 Train Loss: 0.0591 Train accuracy: 0.983 Test accuracy: 0.918
# Epoch: 240 Train Loss: 0.0754 Train accuracy: 0.971 Test accuracy: 0.916
# Epoch: 250 Train Loss: 0.0501 Train accuracy: 0.983 Test accuracy: 0.929
# Epoch: 260 Train Loss: 0.0626 Train accuracy: 0.978 Test accuracy: 0.932
# Epoch: 270 Train Loss: 0.0595 Train accuracy: 0.979 Test accuracy: 0.921
# Epoch: 280 Train Loss: 0.0334 Train accuracy: 0.989 Test accuracy: 0.928
# Epoch: 290 Train Loss: 0.0384 Train accuracy: 0.986 Test accuracy: 0.909
# Epoch: 300 Train Loss: 0.0445 Train accuracy: 0.981 Test accuracy: 0.916
#
#
#  conv_channels=[64, 128],conv_kernels=[[5, 5], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.4259 Train accuracy: 0.87 Test accuracy: 0.872
# Epoch: 20 Train Loss: 0.3234 Train accuracy: 0.889 Test accuracy: 0.9
# Epoch: 30 Train Loss: 0.2285 Train accuracy: 0.921 Test accuracy: 0.914
# Epoch: 40 Train Loss: 0.2469 Train accuracy: 0.907 Test accuracy: 0.92
# Epoch: 50 Train Loss: 0.1414 Train accuracy: 0.948 Test accuracy: 0.932
# Epoch: 60 Train Loss: 0.133 Train accuracy: 0.961 Test accuracy: 0.917
# Epoch: 70 Train Loss: 0.1282 Train accuracy: 0.959 Test accuracy: 0.932
# Epoch: 80 Train Loss: 0.1055 Train accuracy: 0.965 Test accuracy: 0.91
# Epoch: 90 Train Loss: 0.0803 Train accuracy: 0.971 Test accuracy: 0.912
# Epoch: 100 Train Loss: 0.067 Train accuracy: 0.972 Test accuracy: 0.924
# Epoch: 110 Train Loss: 0.0553 Train accuracy: 0.979 Test accuracy: 0.935
# Epoch: 120 Train Loss: 0.0623 Train accuracy: 0.979 Test accuracy: 0.909
# Epoch: 130 Train Loss: 0.0478 Train accuracy: 0.987 Test accuracy: 0.917
# Epoch: 140 Train Loss: 0.0486 Train accuracy: 0.981 Test accuracy: 0.92
# Epoch: 150 Train Loss: 0.0354 Train accuracy: 0.983 Test accuracy: 0.938
# Epoch: 160 Train Loss: 0.0432 Train accuracy: 0.988 Test accuracy: 0.925
# Epoch: 170 Train Loss: 0.0318 Train accuracy: 0.989 Test accuracy: 0.922
# Epoch: 180 Train Loss: 0.0192 Train accuracy: 0.992 Test accuracy: 0.933
# Epoch: 190 Train Loss: 0.0273 Train accuracy: 0.99 Test accuracy: 0.938
# Epoch: 200 Train Loss: 0.0353 Train accuracy: 0.989 Test accuracy: 0.925
# Epoch: 210 Train Loss: 0.0263 Train accuracy: 0.99 Test accuracy: 0.916
# Epoch: 220 Train Loss: 0.0336 Train accuracy: 0.988 Test accuracy: 0.911
# Epoch: 230 Train Loss: 0.0194 Train accuracy: 0.992 Test accuracy: 0.924
# Epoch: 240 Train Loss: 0.0274 Train accuracy: 0.991 Test accuracy: 0.923
# Epoch: 250 Train Loss: 0.0199 Train accuracy: 0.994 Test accuracy: 0.927
# Epoch: 260 Train Loss: 0.0719 Train accuracy: 0.976 Test accuracy: 0.923
# Epoch: 270 Train Loss: 0.0218 Train accuracy: 0.99 Test accuracy: 0.914
# Epoch: 280 Train Loss: 0.0141 Train accuracy: 0.996 Test accuracy: 0.93
# Epoch: 290 Train Loss: 0.0164 Train accuracy: 0.996 Test accuracy: 0.937
# Epoch: 300 Train Loss: 0.0117 Train accuracy: 0.994 Test accuracy: 0.929
#
#
#  conv_channels=[64, 128],conv_kernels=[[3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.5227 Train accuracy: 0.829 Test accuracy: 0.895
# Epoch: 20 Train Loss: 0.3168 Train accuracy: 0.887 Test accuracy: 0.892
# Epoch: 30 Train Loss: 0.2692 Train accuracy: 0.894 Test accuracy: 0.907
# Epoch: 40 Train Loss: 0.2069 Train accuracy: 0.92 Test accuracy: 0.913
# Epoch: 50 Train Loss: 0.1694 Train accuracy: 0.943 Test accuracy: 0.912
# Epoch: 60 Train Loss: 0.1316 Train accuracy: 0.954 Test accuracy: 0.907
# Epoch: 70 Train Loss: 0.1199 Train accuracy: 0.949 Test accuracy: 0.927
# Epoch: 80 Train Loss: 0.1119 Train accuracy: 0.955 Test accuracy: 0.926
# Epoch: 90 Train Loss: 0.0882 Train accuracy: 0.971 Test accuracy: 0.916
# Epoch: 100 Train Loss: 0.0788 Train accuracy: 0.975 Test accuracy: 0.925
# Epoch: 110 Train Loss: 0.0691 Train accuracy: 0.975 Test accuracy: 0.917
# Epoch: 120 Train Loss: 0.0407 Train accuracy: 0.988 Test accuracy: 0.923
# Epoch: 130 Train Loss: 0.0512 Train accuracy: 0.983 Test accuracy: 0.915
# Epoch: 140 Train Loss: 0.0374 Train accuracy: 0.987 Test accuracy: 0.927
# Epoch: 150 Train Loss: 0.0384 Train accuracy: 0.985 Test accuracy: 0.929
# Epoch: 160 Train Loss: 0.0337 Train accuracy: 0.989 Test accuracy: 0.946
# Epoch: 170 Train Loss: 0.0579 Train accuracy: 0.984 Test accuracy: 0.922
# Epoch: 180 Train Loss: 0.0516 Train accuracy: 0.981 Test accuracy: 0.928
# Epoch: 190 Train Loss: 0.0303 Train accuracy: 0.987 Test accuracy: 0.913
# Epoch: 200 Train Loss: 0.0185 Train accuracy: 0.991 Test accuracy: 0.925
# Epoch: 210 Train Loss: 0.0372 Train accuracy: 0.989 Test accuracy: 0.929
# Epoch: 220 Train Loss: 0.0227 Train accuracy: 0.994 Test accuracy: 0.929
# Epoch: 230 Train Loss: 0.0299 Train accuracy: 0.987 Test accuracy: 0.937
# Epoch: 240 Train Loss: 0.0562 Train accuracy: 0.985 Test accuracy: 0.935
# Epoch: 250 Train Loss: 0.029 Train accuracy: 0.991 Test accuracy: 0.908
# Epoch: 260 Train Loss: 0.0175 Train accuracy: 0.993 Test accuracy: 0.911
# Epoch: 270 Train Loss: 0.034 Train accuracy: 0.989 Test accuracy: 0.92
# Epoch: 280 Train Loss: 0.0216 Train accuracy: 0.993 Test accuracy: 0.922
# Epoch: 290 Train Loss: 0.0241 Train accuracy: 0.992 Test accuracy: 0.93
# Epoch: 300 Train Loss: 0.0177 Train accuracy: 0.994 Test accuracy: 0.922
#
#
#  conv_channels=[128, 256],conv_kernels=[[5, 5], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.3519 Train accuracy: 0.899 Test accuracy: 0.895
# Epoch: 20 Train Loss: 0.3042 Train accuracy: 0.908 Test accuracy: 0.898
# Epoch: 30 Train Loss: 0.1704 Train accuracy: 0.937 Test accuracy: 0.921
# Epoch: 40 Train Loss: 0.1579 Train accuracy: 0.939 Test accuracy: 0.925
# Epoch: 50 Train Loss: 0.101 Train accuracy: 0.963 Test accuracy: 0.937
# Epoch: 60 Train Loss: 0.0597 Train accuracy: 0.976 Test accuracy: 0.939
# Epoch: 70 Train Loss: 0.0556 Train accuracy: 0.981 Test accuracy: 0.932
# Epoch: 80 Train Loss: 0.0603 Train accuracy: 0.981 Test accuracy: 0.922
# Epoch: 90 Train Loss: 0.0424 Train accuracy: 0.984 Test accuracy: 0.933
# Epoch: 100 Train Loss: 0.0473 Train accuracy: 0.986 Test accuracy: 0.941
# Epoch: 110 Train Loss: 0.0186 Train accuracy: 0.992 Test accuracy: 0.919
# Epoch: 120 Train Loss: 0.0369 Train accuracy: 0.987 Test accuracy: 0.935
# Epoch: 130 Train Loss: 0.0249 Train accuracy: 0.99 Test accuracy: 0.927
# Epoch: 140 Train Loss: 0.0255 Train accuracy: 0.99 Test accuracy: 0.931
# Epoch: 150 Train Loss: 0.0177 Train accuracy: 0.994 Test accuracy: 0.947
# Epoch: 160 Train Loss: 0.0182 Train accuracy: 0.992 Test accuracy: 0.927
# Epoch: 170 Train Loss: 0.0146 Train accuracy: 0.995 Test accuracy: 0.93
# Epoch: 180 Train Loss: 0.0119 Train accuracy: 0.995 Test accuracy: 0.924
# Epoch: 190 Train Loss: 0.0257 Train accuracy: 0.988 Test accuracy: 0.916
# Epoch: 200 Train Loss: 0.0069 Train accuracy: 0.997 Test accuracy: 0.931
# Epoch: 210 Train Loss: 0.0186 Train accuracy: 0.995 Test accuracy: 0.928
# Epoch: 220 Train Loss: 0.0091 Train accuracy: 0.997 Test accuracy: 0.919
# Epoch: 230 Train Loss: 0.0157 Train accuracy: 0.995 Test accuracy: 0.921
# Epoch: 240 Train Loss: 0.0137 Train accuracy: 0.997 Test accuracy: 0.913
# Epoch: 250 Train Loss: 0.0079 Train accuracy: 0.996 Test accuracy: 0.932
# Epoch: 260 Train Loss: 0.017 Train accuracy: 0.995 Test accuracy: 0.93
# Epoch: 270 Train Loss: 0.0127 Train accuracy: 0.996 Test accuracy: 0.937
# Epoch: 280 Train Loss: 0.014 Train accuracy: 0.996 Test accuracy: 0.922
# Epoch: 290 Train Loss: 0.0157 Train accuracy: 0.994 Test accuracy: 0.935
# Epoch: 300 Train Loss: 0.0129 Train accuracy: 0.997 Test accuracy: 0.931
#
#
#  conv_channels=[128, 256],conv_kernels=[[3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.3956 Train accuracy: 0.865 Test accuracy: 0.893
# Epoch: 20 Train Loss: 0.2221 Train accuracy: 0.927 Test accuracy: 0.916
# Epoch: 30 Train Loss: 0.1798 Train accuracy: 0.939 Test accuracy: 0.916
# Epoch: 40 Train Loss: 0.1383 Train accuracy: 0.954 Test accuracy: 0.922
# Epoch: 50 Train Loss: 0.1131 Train accuracy: 0.959 Test accuracy: 0.931
# Epoch: 60 Train Loss: 0.0879 Train accuracy: 0.968 Test accuracy: 0.932
# Epoch: 70 Train Loss: 0.0576 Train accuracy: 0.98 Test accuracy: 0.93
# Epoch: 80 Train Loss: 0.0402 Train accuracy: 0.988 Test accuracy: 0.923
# Epoch: 90 Train Loss: 0.0377 Train accuracy: 0.987 Test accuracy: 0.926
# Epoch: 100 Train Loss: 0.057 Train accuracy: 0.981 Test accuracy: 0.932
# Epoch: 110 Train Loss: 0.029 Train accuracy: 0.992 Test accuracy: 0.928
# Epoch: 120 Train Loss: 0.0332 Train accuracy: 0.988 Test accuracy: 0.935
# Epoch: 130 Train Loss: 0.0176 Train accuracy: 0.994 Test accuracy: 0.93
# Epoch: 140 Train Loss: 0.0336 Train accuracy: 0.99 Test accuracy: 0.928
# Epoch: 150 Train Loss: 0.0183 Train accuracy: 0.992 Test accuracy: 0.921
# Epoch: 160 Train Loss: 0.0207 Train accuracy: 0.993 Test accuracy: 0.928
# Epoch: 170 Train Loss: 0.021 Train accuracy: 0.991 Test accuracy: 0.928
# Epoch: 180 Train Loss: 0.0077 Train accuracy: 0.997 Test accuracy: 0.926
# Epoch: 190 Train Loss: 0.0208 Train accuracy: 0.993 Test accuracy: 0.93
# Epoch: 200 Train Loss: 0.0092 Train accuracy: 0.999 Test accuracy: 0.927
# Epoch: 210 Train Loss: 0.0137 Train accuracy: 0.994 Test accuracy: 0.933
# Epoch: 220 Train Loss: 0.0171 Train accuracy: 0.995 Test accuracy: 0.933
# Epoch: 230 Train Loss: 0.0119 Train accuracy: 0.997 Test accuracy: 0.929
# Epoch: 240 Train Loss: 0.0146 Train accuracy: 0.996 Test accuracy: 0.934
# Epoch: 250 Train Loss: 0.0068 Train accuracy: 0.998 Test accuracy: 0.935
# Epoch: 260 Train Loss: 0.013 Train accuracy: 0.996 Test accuracy: 0.942
# Epoch: 270 Train Loss: 0.0147 Train accuracy: 0.995 Test accuracy: 0.924
# Epoch: 280 Train Loss: 0.0147 Train accuracy: 0.993 Test accuracy: 0.928
# Epoch: 290 Train Loss: 0.0189 Train accuracy: 0.995 Test accuracy: 0.918
# Epoch: 300 Train Loss: 0.0064 Train accuracy: 0.996 Test accuracy: 0.916
#
#
#  conv_channels=[32, 64, 128],conv_kernels=[[5, 5], [3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.6206 Train accuracy: 0.797 Test accuracy: 0.848
# Epoch: 20 Train Loss: 0.416 Train accuracy: 0.856 Test accuracy: 0.893
# Epoch: 30 Train Loss: 0.3638 Train accuracy: 0.89 Test accuracy: 0.884
# Epoch: 40 Train Loss: 0.3183 Train accuracy: 0.894 Test accuracy: 0.897
# Epoch: 50 Train Loss: 0.2847 Train accuracy: 0.891 Test accuracy: 0.89
# Epoch: 60 Train Loss: 0.2212 Train accuracy: 0.919 Test accuracy: 0.914
# Epoch: 70 Train Loss: 0.2015 Train accuracy: 0.931 Test accuracy: 0.909
# Epoch: 80 Train Loss: 0.2102 Train accuracy: 0.922 Test accuracy: 0.909
# Epoch: 90 Train Loss: 0.1674 Train accuracy: 0.947 Test accuracy: 0.911
# Epoch: 100 Train Loss: 0.159 Train accuracy: 0.944 Test accuracy: 0.902
# Epoch: 110 Train Loss: 0.1577 Train accuracy: 0.94 Test accuracy: 0.922
# Epoch: 120 Train Loss: 0.1082 Train accuracy: 0.955 Test accuracy: 0.916
# Epoch: 130 Train Loss: 0.1243 Train accuracy: 0.958 Test accuracy: 0.934
# Epoch: 140 Train Loss: 0.1087 Train accuracy: 0.96 Test accuracy: 0.907
# Epoch: 150 Train Loss: 0.0939 Train accuracy: 0.962 Test accuracy: 0.913
# Epoch: 160 Train Loss: 0.1045 Train accuracy: 0.964 Test accuracy: 0.912
# Epoch: 170 Train Loss: 0.0879 Train accuracy: 0.966 Test accuracy: 0.912
# Epoch: 180 Train Loss: 0.065 Train accuracy: 0.975 Test accuracy: 0.913
# Epoch: 190 Train Loss: 0.065 Train accuracy: 0.973 Test accuracy: 0.917
# Epoch: 200 Train Loss: 0.0567 Train accuracy: 0.98 Test accuracy: 0.916
# Epoch: 210 Train Loss: 0.0681 Train accuracy: 0.978 Test accuracy: 0.914
# Epoch: 220 Train Loss: 0.0541 Train accuracy: 0.981 Test accuracy: 0.92
# Epoch: 230 Train Loss: 0.036 Train accuracy: 0.989 Test accuracy: 0.908
# Epoch: 240 Train Loss: 0.0566 Train accuracy: 0.982 Test accuracy: 0.917
# Epoch: 250 Train Loss: 0.0331 Train accuracy: 0.988 Test accuracy: 0.921
# Epoch: 260 Train Loss: 0.0305 Train accuracy: 0.992 Test accuracy: 0.913
# Epoch: 270 Train Loss: 0.0305 Train accuracy: 0.988 Test accuracy: 0.92
# Epoch: 280 Train Loss: 0.0377 Train accuracy: 0.984 Test accuracy: 0.915
# Epoch: 290 Train Loss: 0.0322 Train accuracy: 0.986 Test accuracy: 0.917
# Epoch: 300 Train Loss: 0.0365 Train accuracy: 0.988 Test accuracy: 0.924
#
#
#  conv_channels=[32, 64, 128],conv_kernels=[[3, 3], [3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.5675 Train accuracy: 0.798 Test accuracy: 0.834
# Epoch: 20 Train Loss: 0.4307 Train accuracy: 0.861 Test accuracy: 0.889
# Epoch: 30 Train Loss: 0.3492 Train accuracy: 0.878 Test accuracy: 0.887
# Epoch: 40 Train Loss: 0.289 Train accuracy: 0.897 Test accuracy: 0.894
# Epoch: 50 Train Loss: 0.2434 Train accuracy: 0.916 Test accuracy: 0.901
# Epoch: 60 Train Loss: 0.2257 Train accuracy: 0.922 Test accuracy: 0.909
# Epoch: 70 Train Loss: 0.2105 Train accuracy: 0.929 Test accuracy: 0.911
# Epoch: 80 Train Loss: 0.1665 Train accuracy: 0.941 Test accuracy: 0.916
# Epoch: 90 Train Loss: 0.1525 Train accuracy: 0.938 Test accuracy: 0.907
# Epoch: 100 Train Loss: 0.1547 Train accuracy: 0.938 Test accuracy: 0.923
# Epoch: 110 Train Loss: 0.1156 Train accuracy: 0.962 Test accuracy: 0.919
# Epoch: 120 Train Loss: 0.1106 Train accuracy: 0.96 Test accuracy: 0.914
# Epoch: 130 Train Loss: 0.1268 Train accuracy: 0.959 Test accuracy: 0.899
# Epoch: 140 Train Loss: 0.0869 Train accuracy: 0.969 Test accuracy: 0.919
# Epoch: 150 Train Loss: 0.0952 Train accuracy: 0.963 Test accuracy: 0.91
# Epoch: 160 Train Loss: 0.071 Train accuracy: 0.973 Test accuracy: 0.913
# Epoch: 170 Train Loss: 0.0658 Train accuracy: 0.975 Test accuracy: 0.921
# Epoch: 180 Train Loss: 0.0634 Train accuracy: 0.981 Test accuracy: 0.925
# Epoch: 190 Train Loss: 0.0518 Train accuracy: 0.981 Test accuracy: 0.918
# Epoch: 200 Train Loss: 0.0585 Train accuracy: 0.978 Test accuracy: 0.914
# Epoch: 210 Train Loss: 0.0393 Train accuracy: 0.987 Test accuracy: 0.911
# Epoch: 220 Train Loss: 0.0465 Train accuracy: 0.983 Test accuracy: 0.926
# Epoch: 230 Train Loss: 0.0806 Train accuracy: 0.974 Test accuracy: 0.916
# Epoch: 240 Train Loss: 0.0465 Train accuracy: 0.983 Test accuracy: 0.917
# Epoch: 250 Train Loss: 0.0278 Train accuracy: 0.992 Test accuracy: 0.922
# Epoch: 260 Train Loss: 0.0281 Train accuracy: 0.992 Test accuracy: 0.929
# Epoch: 270 Train Loss: 0.053 Train accuracy: 0.989 Test accuracy: 0.917
# Epoch: 280 Train Loss: 0.0394 Train accuracy: 0.987 Test accuracy: 0.929
# Epoch: 290 Train Loss: 0.0262 Train accuracy: 0.991 Test accuracy: 0.925
# Epoch: 300 Train Loss: 0.034 Train accuracy: 0.988 Test accuracy: 0.908
#
#
#  conv_channels=[64, 128, 256],conv_kernels=[[5, 5], [3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.4694 Train accuracy: 0.857 Test accuracy: 0.878
# Epoch: 20 Train Loss: 0.3619 Train accuracy: 0.871 Test accuracy: 0.892
# Epoch: 30 Train Loss: 0.2307 Train accuracy: 0.919 Test accuracy: 0.914
# Epoch: 40 Train Loss: 0.1983 Train accuracy: 0.92 Test accuracy: 0.922
# Epoch: 50 Train Loss: 0.1674 Train accuracy: 0.942 Test accuracy: 0.925
# Epoch: 60 Train Loss: 0.1423 Train accuracy: 0.949 Test accuracy: 0.918
# Epoch: 70 Train Loss: 0.1012 Train accuracy: 0.966 Test accuracy: 0.92
# Epoch: 80 Train Loss: 0.0748 Train accuracy: 0.971 Test accuracy: 0.913
# Epoch: 90 Train Loss: 0.0741 Train accuracy: 0.971 Test accuracy: 0.917
# Epoch: 100 Train Loss: 0.0617 Train accuracy: 0.976 Test accuracy: 0.913
# Epoch: 110 Train Loss: 0.0317 Train accuracy: 0.996 Test accuracy: 0.938
# Epoch: 120 Train Loss: 0.0401 Train accuracy: 0.98 Test accuracy: 0.931
# Epoch: 130 Train Loss: 0.0379 Train accuracy: 0.987 Test accuracy: 0.909
# Epoch: 140 Train Loss: 0.0213 Train accuracy: 0.996 Test accuracy: 0.931
# Epoch: 150 Train Loss: 0.0312 Train accuracy: 0.991 Test accuracy: 0.94
# Epoch: 160 Train Loss: 0.022 Train accuracy: 0.993 Test accuracy: 0.929
# Epoch: 170 Train Loss: 0.0209 Train accuracy: 0.991 Test accuracy: 0.913
# Epoch: 180 Train Loss: 0.0211 Train accuracy: 0.994 Test accuracy: 0.923
# Epoch: 190 Train Loss: 0.0149 Train accuracy: 0.994 Test accuracy: 0.923
# Epoch: 200 Train Loss: 0.0195 Train accuracy: 0.993 Test accuracy: 0.924
# Epoch: 210 Train Loss: 0.0126 Train accuracy: 0.993 Test accuracy: 0.914
# Epoch: 220 Train Loss: 0.0181 Train accuracy: 0.994 Test accuracy: 0.927
# Epoch: 230 Train Loss: 0.0127 Train accuracy: 0.995 Test accuracy: 0.914
# Epoch: 240 Train Loss: 0.0354 Train accuracy: 0.99 Test accuracy: 0.931
# Epoch: 250 Train Loss: 0.0072 Train accuracy: 0.996 Test accuracy: 0.924
# Epoch: 260 Train Loss: 0.027 Train accuracy: 0.991 Test accuracy: 0.915
# Epoch: 270 Train Loss: 0.014 Train accuracy: 0.997 Test accuracy: 0.94
# Epoch: 280 Train Loss: 0.0149 Train accuracy: 0.995 Test accuracy: 0.927
# Epoch: 290 Train Loss: 0.0093 Train accuracy: 0.997 Test accuracy: 0.934
# Epoch: 300 Train Loss: 0.0082 Train accuracy: 0.996 Test accuracy: 0.919
#
#
#  conv_channels=[64, 128, 256],conv_kernels=[[3, 3], [3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.4481 Train accuracy: 0.86 Test accuracy: 0.888
# Epoch: 20 Train Loss: 0.2859 Train accuracy: 0.908 Test accuracy: 0.893
# Epoch: 30 Train Loss: 0.2518 Train accuracy: 0.914 Test accuracy: 0.912
# Epoch: 40 Train Loss: 0.1857 Train accuracy: 0.934 Test accuracy: 0.921
# Epoch: 50 Train Loss: 0.1536 Train accuracy: 0.946 Test accuracy: 0.921
# Epoch: 60 Train Loss: 0.1159 Train accuracy: 0.968 Test accuracy: 0.914
# Epoch: 70 Train Loss: 0.0736 Train accuracy: 0.978 Test accuracy: 0.926
# Epoch: 80 Train Loss: 0.0788 Train accuracy: 0.975 Test accuracy: 0.913
# Epoch: 90 Train Loss: 0.0662 Train accuracy: 0.976 Test accuracy: 0.92
# Epoch: 100 Train Loss: 0.0515 Train accuracy: 0.982 Test accuracy: 0.918
# Epoch: 110 Train Loss: 0.0338 Train accuracy: 0.985 Test accuracy: 0.91
# Epoch: 120 Train Loss: 0.038 Train accuracy: 0.987 Test accuracy: 0.92
# Epoch: 130 Train Loss: 0.0438 Train accuracy: 0.982 Test accuracy: 0.924
# Epoch: 140 Train Loss: 0.0235 Train accuracy: 0.991 Test accuracy: 0.925
# Epoch: 150 Train Loss: 0.0282 Train accuracy: 0.987 Test accuracy: 0.914
# Epoch: 160 Train Loss: 0.0129 Train accuracy: 0.998 Test accuracy: 0.922
# Epoch: 170 Train Loss: 0.0252 Train accuracy: 0.991 Test accuracy: 0.926
# Epoch: 180 Train Loss: 0.021 Train accuracy: 0.99 Test accuracy: 0.937
# Epoch: 190 Train Loss: 0.0222 Train accuracy: 0.993 Test accuracy: 0.927
# Epoch: 200 Train Loss: 0.0131 Train accuracy: 0.996 Test accuracy: 0.926
# Epoch: 210 Train Loss: 0.0107 Train accuracy: 0.998 Test accuracy: 0.92
# Epoch: 220 Train Loss: 0.0114 Train accuracy: 0.995 Test accuracy: 0.921
# Epoch: 230 Train Loss: 0.0161 Train accuracy: 0.995 Test accuracy: 0.919
# Epoch: 240 Train Loss: 0.0101 Train accuracy: 0.996 Test accuracy: 0.922
# Epoch: 250 Train Loss: 0.0102 Train accuracy: 0.997 Test accuracy: 0.919
# Epoch: 260 Train Loss: 0.0107 Train accuracy: 0.997 Test accuracy: 0.93
# Epoch: 270 Train Loss: 0.009 Train accuracy: 0.998 Test accuracy: 0.938
# Epoch: 280 Train Loss: 0.0178 Train accuracy: 0.993 Test accuracy: 0.91
# Epoch: 290 Train Loss: 0.0071 Train accuracy: 0.997 Test accuracy: 0.921
# Epoch: 300 Train Loss: 0.0098 Train accuracy: 0.997 Test accuracy: 0.919
#
#
#  conv_channels=[128, 256, 512],conv_kernels=[[5, 5], [3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.3294 Train accuracy: 0.889 Test accuracy: 0.896
# Epoch: 20 Train Loss: 0.2023 Train accuracy: 0.93 Test accuracy: 0.928
# Epoch: 30 Train Loss: 0.1538 Train accuracy: 0.953 Test accuracy: 0.931
# Epoch: 40 Train Loss: 0.0812 Train accuracy: 0.974 Test accuracy: 0.922
# Epoch: 50 Train Loss: 0.0603 Train accuracy: 0.98 Test accuracy: 0.923
# Epoch: 60 Train Loss: 0.0338 Train accuracy: 0.99 Test accuracy: 0.92
# Epoch: 70 Train Loss: 0.0274 Train accuracy: 0.991 Test accuracy: 0.936
# Epoch: 80 Train Loss: 0.0159 Train accuracy: 0.997 Test accuracy: 0.919
# Epoch: 90 Train Loss: 0.019 Train accuracy: 0.992 Test accuracy: 0.92
# Epoch: 100 Train Loss: 0.0212 Train accuracy: 0.994 Test accuracy: 0.926
# Epoch: 110 Train Loss: 0.0138 Train accuracy: 0.996 Test accuracy: 0.933
# Epoch: 120 Train Loss: 0.0113 Train accuracy: 0.997 Test accuracy: 0.906
# Epoch: 130 Train Loss: 0.0216 Train accuracy: 0.993 Test accuracy: 0.932
# Epoch: 140 Train Loss: 0.0139 Train accuracy: 0.997 Test accuracy: 0.94
# Epoch: 150 Train Loss: 0.005 Train accuracy: 0.998 Test accuracy: 0.928
# Epoch: 160 Train Loss: 0.0053 Train accuracy: 0.998 Test accuracy: 0.93
# Epoch: 170 Train Loss: 0.0014 Train accuracy: 1.0 Test accuracy: 0.916
# Epoch: 180 Train Loss: 0.005 Train accuracy: 0.998 Test accuracy: 0.935
# Epoch: 190 Train Loss: 0.0034 Train accuracy: 0.998 Test accuracy: 0.926
# Epoch: 200 Train Loss: 0.0041 Train accuracy: 0.999 Test accuracy: 0.937
# Epoch: 210 Train Loss: 0.0053 Train accuracy: 0.997 Test accuracy: 0.934
# Epoch: 220 Train Loss: 0.01 Train accuracy: 0.997 Test accuracy: 0.92
# Epoch: 230 Train Loss: 0.0032 Train accuracy: 1.0 Test accuracy: 0.915
# Epoch: 240 Train Loss: 0.0032 Train accuracy: 0.999 Test accuracy: 0.918
# Epoch: 250 Train Loss: 0.0023 Train accuracy: 0.999 Test accuracy: 0.933
# Epoch: 260 Train Loss: 0.0007 Train accuracy: 1.0 Test accuracy: 0.938
# Epoch: 270 Train Loss: 0.0006 Train accuracy: 1.0 Test accuracy: 0.932
# Epoch: 280 Train Loss: 0.0009 Train accuracy: 1.0 Test accuracy: 0.91
# Epoch: 290 Train Loss: 0.0056 Train accuracy: 0.999 Test accuracy: 0.932
# Epoch: 300 Train Loss: 0.0024 Train accuracy: 0.999 Test accuracy: 0.938
#
#
#  conv_channels=[128, 256, 512],conv_kernels=[[3, 3], [3, 3], [3, 3]]
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# Epoch: 10 Train Loss: 0.3712 Train accuracy: 0.877 Test accuracy: 0.901
# Epoch: 20 Train Loss: 0.2741 Train accuracy: 0.906 Test accuracy: 0.902
# Epoch: 30 Train Loss: 0.1575 Train accuracy: 0.943 Test accuracy: 0.927
# Epoch: 40 Train Loss: 0.1392 Train accuracy: 0.945 Test accuracy: 0.922
# Epoch: 50 Train Loss: 0.0957 Train accuracy: 0.966 Test accuracy: 0.934
# Epoch: 60 Train Loss: 0.0684 Train accuracy: 0.977 Test accuracy: 0.925
# Epoch: 70 Train Loss: 0.0363 Train accuracy: 0.985 Test accuracy: 0.929
# Epoch: 80 Train Loss: 0.0297 Train accuracy: 0.989 Test accuracy: 0.934
# Epoch: 90 Train Loss: 0.0324 Train accuracy: 0.992 Test accuracy: 0.928
# Epoch: 100 Train Loss: 0.0175 Train accuracy: 0.993 Test accuracy: 0.931
# Epoch: 110 Train Loss: 0.014 Train accuracy: 0.997 Test accuracy: 0.936
# Epoch: 120 Train Loss: 0.0138 Train accuracy: 0.996 Test accuracy: 0.928
# Epoch: 130 Train Loss: 0.0141 Train accuracy: 0.995 Test accuracy: 0.923
# Epoch: 140 Train Loss: 0.0123 Train accuracy: 0.996 Test accuracy: 0.934
# Epoch: 150 Train Loss: 0.0214 Train accuracy: 0.992 Test accuracy: 0.931
# Epoch: 160 Train Loss: 0.0031 Train accuracy: 0.999 Test accuracy: 0.925
# Epoch: 170 Train Loss: 0.033 Train accuracy: 0.993 Test accuracy: 0.936
# Epoch: 180 Train Loss: 0.0055 Train accuracy: 0.999 Test accuracy: 0.926
# Epoch: 190 Train Loss: 0.0087 Train accuracy: 0.998 Test accuracy: 0.938
# Epoch: 200 Train Loss: 0.0129 Train accuracy: 0.993 Test accuracy: 0.928
# Epoch: 210 Train Loss: 0.005 Train accuracy: 0.999 Test accuracy: 0.916
# Epoch: 220 Train Loss: 0.0067 Train accuracy: 0.998 Test accuracy: 0.914
# Epoch: 230 Train Loss: 0.0369 Train accuracy: 0.99 Test accuracy: 0.921
# Epoch: 240 Train Loss: 0.0077 Train accuracy: 0.997 Test accuracy: 0.93
# Epoch: 250 Train Loss: 0.0037 Train accuracy: 0.999 Test accuracy: 0.941
# Epoch: 260 Train Loss: 0.0084 Train accuracy: 0.997 Test accuracy: 0.921
# Epoch: 270 Train Loss: 0.007 Train accuracy: 0.999 Test accuracy: 0.937
# Epoch: 280 Train Loss: 0.0127 Train accuracy: 0.995 Test accuracy: 0.924
# Epoch: 290 Train Loss: 0.0067 Train accuracy: 0.999 Test accuracy: 0.935
# Epoch: 300 Train Loss: 0.0022 Train accuracy: 0.999 Test accuracy: 0.905
